# %%
#Name: Supreeth Hassan Ravindra
#CWID: 20020533
#HW-08: ANN

# %%
#Importing the required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Loading the dataset
df = pd.read_csv('wisc_bc_ContinuousVar.csv')

# Display the first few rows of the dataset
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
#checking for null values
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# Removing rows with missing values
df = df.dropna()

# %%
# Label encode the 'diagnosis' column
label_encoder = LabelEncoder()
df['diagnosis'] = label_encoder.fit_transform(df['diagnosis'])

# %%
# Separate features and labels
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model_ANN = Sequential()
model_ANN.add(Dense(5, input_dim=X_train.shape[1], activation='relu'))
model_ANN.add(Dense(1, activation='sigmoid'))

# Compile the model
model_ANN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model_ANN.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 1ms/step - loss: 0.9375 - accuracy: 0.6307
# Epoch 2/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8110 - accuracy: 0.6407
# Epoch 3/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7100 - accuracy: 0.6508
# Epoch 4/50
# 13/13 [==============================] - 0s 715us/step - loss: 0.6226 - accuracy: 0.6784
# Epoch 5/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5590 - accuracy: 0.7060
# Epoch 6/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5067 - accuracy: 0.7362
# Epoch 7/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4663 - accuracy: 0.7688
# Epoch 8/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4365 - accuracy: 0.8090
# Epoch 9/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4133 - accuracy: 0.8266
# Epoch 10/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3935 - accuracy: 0.8442
# Epoch 11/50
# 13/13 [==============================] - 0s 683us/step - loss: 0.3787 - accuracy: 0.8744
# Epoch 12/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3664 - accuracy: 0.8920
# Epoch 13/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8970
# Epoch 14/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8995
# Epoch 15/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.9070
# Epoch 16/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3307 - accuracy: 0.9246
# Epoch 17/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3241 - accuracy: 0.9296
# Epoch 18/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3179 - accuracy: 0.9372
# Epoch 19/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3122 - accuracy: 0.9372
# Epoch 20/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3068 - accuracy: 0.9372
# Epoch 21/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.9422
# Epoch 22/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2974 - accuracy: 0.9447
# Epoch 23/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2929 - accuracy: 0.9523
# Epoch 24/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2888 - accuracy: 0.9523
# Epoch 25/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2846 - accuracy: 0.9548
# Epoch 26/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2809 - accuracy: 0.9648
# Epoch 27/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.9648
# Epoch 28/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2736 - accuracy: 0.9648
# Epoch 29/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2702 - accuracy: 0.9673
# Epoch 30/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2669 - accuracy: 0.9673
# Epoch 31/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.9698
# Epoch 32/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 0.9698
# Epoch 33/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2575 - accuracy: 0.9724
# Epoch 34/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.9724
# Epoch 35/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2520 - accuracy: 0.9749
# Epoch 36/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.9724
# Epoch 37/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.9724
# Epoch 38/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2441 - accuracy: 0.9698
# Epoch 39/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.9698
# Epoch 40/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2394 - accuracy: 0.9698
# Epoch 41/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2370 - accuracy: 0.9698
# Epoch 42/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2348 - accuracy: 0.9724
# Epoch 43/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9724
# Epoch 44/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2304 - accuracy: 0.9724
# Epoch 45/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9724
# Epoch 46/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2263 - accuracy: 0.9724
# Epoch 47/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2243 - accuracy: 0.9724
# Epoch 48/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2224 - accuracy: 0.9724
# Epoch 49/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2204 - accuracy: 0.9724
# Epoch 50/50
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2185 - accuracy: 0.9724

# %%
# Predictions on the test set
y_pred_prob = model_ANN.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 6/6 [==============================] - 0s 1ms/step

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
# Display the results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{classification_rep}")
# Out:
# Accuracy: 0.9883040935672515
# Confusion Matrix:
# [[108   0]
#  [  2  61]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       108
#            1       1.00      0.97      0.98        63
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.98      0.99       171
# weighted avg       0.99      0.99      0.99       171
